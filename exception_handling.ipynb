# %%
try:
    print("Exception handling")
    a = 10
    b=0
    print(a/b)


except ZeroDivisionError:
    print("divide by zero error")
# Out:
# Exception handling
# divide by zero error

# %%
try:
    print("Exception handling")
    a = 10
    b=0
    print(a/b)


except ZeroDivisionError:
    print("divide by zero error")
