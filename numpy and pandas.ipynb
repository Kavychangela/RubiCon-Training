# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
months = ["jan", "feb", "mar"]
sales = [15, 20, 99]

# %%
plt.plot(months, sales)

# %%
plt.bar(months, sales)
plt.title("Sales Data")
plt.xlabel("Month")
plt.ylabel("Sales")
# Out:
# Text(0, 0.5, 'Sales')

# %%
import sqlite3
